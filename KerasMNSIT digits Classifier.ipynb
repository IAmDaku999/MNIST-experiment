# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)

# %%
import tensorflow as tf
from  keras import Sequential
from keras.layers import Dense
import pandas as pd

# %%
model=Sequential([
    Dense(units=10,activation='sigmoid'),
    Dense(units=10,activation='sigmoid'),
    Dense(units=10,activation='sigmoid')
])

# %%
df=pd.read_csv('/content/sample_data/mnist_train_small.csv')
no_row=df.shape[0]
no_col=df.shape[1]
exampleNo=df.shape[1]

labelSet=df.iloc[:,0]
x_test=df.iloc[:,1:no_col]
y_test=[]
print(x_test)

# %%
from keras.losses import categorical_crossentropy
model.compile(loss=categorical_crossentropy())

model.fit(x_test,y_test,epochs=30)

# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.utils import to_categorical

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.reshape((x_train.shape[0], 28, 28, 1))
x_test = x_test.reshape((x_test.shape[0], 28, 28, 1))
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# Convert the labels to one-hot vectors
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Create the model
model = Sequential()
model.add(Flatten(input_shape=(28, 28, 1)))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(loss=SparseCategoricalCrossentropy(), optimizer='adam', metrics=['accuracy'])


score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Train the model
model.fit(x_train, y_train, epochs=10)

# Evaluate the model
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 2.3891282081604004
# Test accuracy: 0.10679999738931656
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2788 - accuracy: 0.9203
# Test loss: 0.13897471129894257
# Test accuracy: 0.9589999914169312
